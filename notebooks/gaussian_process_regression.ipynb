# %%
import math
import os
import torch
import gpytorch
from matplotlib import pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Training data is 100 points in [0,1] inclusive regularly spaced
train_x = torch.linspace(0, 1, 100)
# True function is sin(2*pi*x) with Gaussian noise
train_y = torch.sin(train_x * (2 * math.pi)) + torch.randn(train_x.size()) * math.sqrt(0.04)

# %%
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# %%
# initialize likelihood and model
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = ExactGPModel(train_x, train_y, likelihood)

# # this is for running the notebook in our testing framework
# smoke_test = ('CI' in os.environ)
# training_iter = 2 if smoke_test else 50

# %%
smoke_test = ('CI' in os.environ)
training_iter = 2 if smoke_test else 50


# Find optimal model hyperparameters
model.train()
likelihood.train()

# Use the adam optimizer
optimizer = torch.optim.Adam([
    {'params': model.parameters()},  # Includes GaussianLikelihood parameters
], lr=0.1)

# "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

# %%
for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(train_x)
    # Calc loss and backprop gradients
    loss = -mll(output, train_y)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))
    optimizer.step()
# Out:
# Iter 1/50 - Loss: 0.921   lengthscale: 0.693   noise: 0.693
# Iter 2/50 - Loss: 0.890   lengthscale: 0.644   noise: 0.644
# Iter 3/50 - Loss: 0.857   lengthscale: 0.598   noise: 0.598
# Iter 4/50 - Loss: 0.820   lengthscale: 0.555   noise: 0.554
# Iter 5/50 - Loss: 0.779   lengthscale: 0.514   noise: 0.513
# Iter 6/50 - Loss: 0.735   lengthscale: 0.475   noise: 0.474
# Iter 7/50 - Loss: 0.688   lengthscale: 0.439   noise: 0.437
# Iter 8/50 - Loss: 0.640   lengthscale: 0.404   noise: 0.402
# Iter 9/50 - Loss: 0.595   lengthscale: 0.372   noise: 0.370
# Iter 10/50 - Loss: 0.554   lengthscale: 0.342   noise: 0.339
# Iter 11/50 - Loss: 0.516   lengthscale: 0.315   noise: 0.311
# Iter 12/50 - Loss: 0.482   lengthscale: 0.293   noise: 0.284
# Iter 13/50 - Loss: 0.448   lengthscale: 0.274   noise: 0.260
# Iter 14/50 - Loss: 0.416   lengthscale: 0.259   noise: 0.237
# Iter 15/50 - Loss: 0.384   lengthscale: 0.247   noise: 0.216
# Iter 16/50 - Loss: 0.353   lengthscale: 0.238   noise: 0.197
# Iter 17/50 - Loss: 0.322   lengthscale: 0.232   noise: 0.180
# Iter 18/50 - Loss: 0.291   lengthscale: 0.228   noise: 0.164
# Iter 19/50 - Loss: 0.261   lengthscale: 0.226   noise: 0.149
# Iter 20/50 - Loss: 0.232   lengthscale: 0.226   noise: 0.136
# Iter 21/50 - Loss: 0.204   lengthscale: 0.227   noise: 0.123
# Iter 22/50 - Loss: 0.177   lengthscale: 0.231   noise: 0.112
# Iter 23/50 - Loss: 0.152   lengthscale: 0.235   noise: 0.102
# Iter 24/50 - Loss: 0.129   lengthscale: 0.241   noise: 0.094
# Iter 25/50 - Loss: 0.108   lengthscale: 0.248   noise: 0.085
# Iter 26/50 - Loss: 0.090   lengthscale: 0.255   noise: 0.078
# Iter 27/50 - Loss: 0.075   lengthscale: 0.264   noise: 0.072
# Iter 28/50 - Loss: 0.062   lengthscale: 0.272   noise: 0.066
# Iter 29/50 - Loss: 0.053   lengthscale: 0.281   noise: 0.061
# Iter 30/50 - Loss: 0.047   lengthscale: 0.290   noise: 0.057
# Iter 31/50 - Loss: 0.044   lengthscale: 0.298   noise: 0.053
# Iter 32/50 - Loss: 0.044   lengthscale: 0.306   noise: 0.049
# Iter 33/50 - Loss: 0.046   lengthscale: 0.311   noise: 0.046
# Iter 34/50 - Loss: 0.049   lengthscale: 0.315   noise: 0.044
# Iter 35/50 - Loss: 0.053   lengthscale: 0.317   noise: 0.042
# Iter 36/50 - Loss: 0.056   lengthscale: 0.317   noise: 0.040
# Iter 37/50 - Loss: 0.060   lengthscale: 0.315   noise: 0.039
# Iter 38/50 - Loss: 0.062   lengthscale: 0.311   noise: 0.038
# Iter 39/50 - Loss: 0.064   lengthscale: 0.307   noise: 0.037
# Iter 40/50 - Loss: 0.065   lengthscale: 0.301   noise: 0.037
# Iter 41/50 - Loss: 0.064   lengthscale: 0.296   noise: 0.037
# Iter 42/50 - Loss: 0.064   lengthscale: 0.291   noise: 0.037
# Iter 43/50 - Loss: 0.062   lengthscale: 0.286   noise: 0.038
# Iter 44/50 - Loss: 0.060   lengthscale: 0.282   noise: 0.038
# Iter 45/50 - Loss: 0.058   lengthscale: 0.278   noise: 0.039
# Iter 46/50 - Loss: 0.055   lengthscale: 0.276   noise: 0.040
# Iter 47/50 - Loss: 0.053   lengthscale: 0.274   noise: 0.041
# Iter 48/50 - Loss: 0.050   lengthscale: 0.274   noise: 0.042
# Iter 49/50 - Loss: 0.048   lengthscale: 0.274   noise: 0.043
# Iter 50/50 - Loss: 0.047   lengthscale: 0.275   noise: 0.044

# %%
# Get into evaluation (predictive posterior) mode
model.eval()
likelihood.eval()

# Test points are regularly spaced along [0,1]
# Make predictions by feeding model through likelihood
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    test_x = torch.linspace(0, 1, 51)
    observed_pred = likelihood(model(test_x))

# %%
with torch.no_grad():
    # Initialize plot
    f, ax = plt.subplots(1, 1, figsize=(4, 3))

    # Get upper and lower confidence bounds
    lower, upper = observed_pred.confidence_region()
    # Plot training data as black stars
    ax.plot(train_x.numpy(), train_y.numpy(), 'k*')
    # Plot predictive means as blue line
    ax.plot(test_x.numpy(), observed_pred.mean.numpy(), 'b')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(test_x.numpy(), lower.numpy(), upper.numpy(), alpha=0.5)
    ax.set_ylim([-3, 3])
    ax.legend(['Observed Data', 'Mean', 'Confidence'])
